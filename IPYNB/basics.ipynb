# %%
import ROOT
# %jsroot

# %%
c = ROOT.TCanvas()

# %% [markdown]
# ## Plotting a Function

# %%
f1 = ROOT.TF1("func1", "sin(x)/x", 0, 10)
f1.Draw()
c.Draw()
# Out:
# <div id="root_plot_1723742080813" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1723742080813(Core) {
# ...

# %% [markdown]
# ## Excercise 1 : Plotting a 2D function

# %%
f2 = ROOT.TF2("func2", "sin(x)*sin(y)/(x*y)", -10, 10, -10, 10)
f2.Draw("surf1")
c.Draw()
# Out:
# <div id="root_plot_1723742084489" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1723742084489(Core) {
# ...

# %% [markdown]
# ## Histogram

# %%
h1 = ROOT.TH1D("hist1", "Example Histogram", 100, -3, 3)
h1.FillRandom("gaus", 10000)
h1.Draw()
c.Draw()
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: hist1 (Potential memory leak).
# <div id="root_plot_1723742089446" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1723742089446(Core) {
# ...

# %% [markdown]
# ## Custom Histogram

# %%
myfun = ROOT.TF1("myfun", "sin(x)", 0, ROOT.TMath.Pi())
h = ROOT.TH1D("hist1", "Custom Histogram", 100, 0, ROOT.TMath.Pi())
h.FillRandom("myfun", 10000)
h.Draw("e")
c.Draw()
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: hist1 (Potential memory leak).
# <div id="root_plot_1723742110286" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1723742110286(Core) {
# ...

# %% [markdown]
# ## Fitting Histogram to Gaus

# %%
c2 = ROOT.TCanvas()

# %%
h_FIT = ROOT.TH1D("hist_fit", "Histogram", 100, -3, 3)
h_FIT.FillRandom("gaus", 10000)
h_FIT.Fit("gaus")
h_FIT.Draw()
c2.Draw()
ROOT.gStyle.SetOptFit(0o0001)
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      126.382
# NDf                       =           97
# Edm                       =  1.65929e-09
# NCalls                    =           63
# Constant                  =      244.145   +/-   3.00128
# Mean                      =  -0.00129906   +/-   0.00987758
# Sigma                     =     0.969951   +/-   0.00699089   	 (limited)
# Warning in <TROOT::Append>: Replacing existing TH1: hist_fit (Potential memory leak).
# <div id="root_plot_1723742139492" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1723742139492(Core) {
# ...

# %%
file1 = ROOT.TFile('../DATA/histogram.root')
h_cf = file1.Get('hist2')
fitFun = ROOT.TF1('fitFun','gaus(0) + gaus(3)', 0, 14)
fitFun.SetParameters(5., 2., 1., 1., 10., 1.)
h_cf.Fit("fitFun")
h_cf.Draw()
c2.Draw()
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      103.514
# NDf                       =           94
# Edm                       =   3.3365e-06
# NCalls                    =         1818
# p0                        =      185.815   +/-   3.92256
# p1                        =      2.98164   +/-   0.0352414
# p2                        =      1.48598   +/-   0.0321153
# p3                        =      110.227   +/-   2.1925
# p4                        =      10.1233   +/-   0.0751521
# p5                        =      3.10616   +/-   0.0970591
# <div id="root_plot_1723742451699" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1723742451699(Core) {
# ...
