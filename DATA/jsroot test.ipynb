# %%
# %%javascript
# var s = document.createElement('script');
# s.src='https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js';
# document.body.appendChild(s);

# %%
from ROOT import TH1D, TCanvas
# %jsroot off

# %%
my_canvas = TCanvas("mycanvas","canvas title",800,600)
example = TH1D("example","example histogram",100,-3,3)
example.FillRandom("gaus",10000)
example.Draw("E")
exampleFit = example.Fit("gaus")
example.Draw()
my_canvas.Draw()
# Out:
#  FCN=127.036 FROM MIGRAD    STATUS=CONVERGED      59 CALLS          60 TOTAL
#                      EDM=8.16709e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.42647e+02   2.96775e+00   1.34923e-02   4.49705e-05
#    2  Mean        -5.33542e-03   9.93636e-03   5.48713e-05  -5.81442e-03
#    3  Sigma        9.76006e-01   6.93352e-03   1.07286e-05   4.43302e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: mycanvas
# Warning in <TROOT::Append>: Replacing existing TH1: example (Potential memory leak).
