// %%
ROOT::RDataFrame dataframe("tree1","experiment.root");
TCanvas canvas;
auto pt_calc = [](float x,float y)
    {
        return std::sqrt(x*x+y*y);
    };
auto pt_hist = dataframe.Define("pt",pt_calc,{"px","py"}).Histo1D("pt");

// %%
%%time
pt_hist->Draw();
// Out:
// Time: 1.7050185203552246 seconds.

// %%
canvas.Draw();

// %%
pt_calc
// Out:
// ((lambda) &) @0x7f1f26930440
