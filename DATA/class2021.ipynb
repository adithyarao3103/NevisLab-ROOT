# %%
import ROOT
grams = ROOT.TH1D("example","This is yet another test",100,-3,3)
grams.FillRandom("gaus",1000)
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: example (Potential memory leak).

# %%
canvas = ROOT.TCanvas()
grams.Draw("e")
canvas.Draw()
