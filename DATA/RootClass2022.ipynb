# %%
import ROOT
somename = ROOT.TH1D("literal","This is an example histogram",100,-3,3)
somename.FillRandom("gaus",10000)
canvas = ROOT.TCanvas()
somename.Draw()
canvas.Draw()
# Out:
# Welcome to JupyROOT 6.24/06

# %%
somename.Draw("e")
canvas.Draw()
